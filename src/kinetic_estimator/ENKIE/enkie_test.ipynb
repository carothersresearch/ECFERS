# %%
import numpy as np

from enkie import Enzyme, Metabolite, ModularRateLaw, Reaction, CompartmentParameters, ParameterSpace

# %%
_2pg = Metabolite("2pg_c", "bigg.metabolite:2pg", "c", 4, -3)
_3pg = Metabolite("3pg_c", "bigg.metabolite:3pg", "c", 4, -3)

# %%
PGM = Reaction("PGM", "bigg.reaction:PGM", [_2pg, _3pg], np.array([-1, 1]))
 # 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase (gpmA).
PGM_law_1 = ModularRateLaw("PGM_gpmA", PGM)
P62707 = Enzyme("5.4.2.11", ["P62707"], ["b0755"])
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\urllib\request.py:1354, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1353 try:
# -> 1354     h.request(req.get_method(), req.selector, req.data, headers,
#    1355               encode_chunked=req.has_header('Transfer-encoding'))
#    1356 except OSError as err: # timeout error
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\http\client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\http\client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\http\client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\http\client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\http\client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\http\client.py:1425, in HTTPSConnection.connect(self)
#    1423     server_hostname = self.host
# -> 1425 self.sock = self._context.wrap_socket(self.sock,
#    1426                                       server_hostname=server_hostname)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1131)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# c:\Users\Diego Alba\Documents\GitHub\ECFERS\src\kinetic_estimator\ENKIE\enkie_test.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> PGM = Reaction("PGM", "bigg.reaction:PGM", [_2pg, _3pg], np.array([-1, 1]))
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>  # 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase (gpmA).
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> PGM_law_1 = ModularRateLaw("PGM_gpmA", PGM)
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> P62707 = Enzyme("5.4.2.11", ["P62707"], ["b0755"])
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\enkie\modular_rate_law.py:59, in ModularRateLaw.__init__(self, rid, reaction, denominator, cooperativity)
#      57 self._denominator = denominator
#      58 self._h = cooperativity
# ---> 59 self._kin_idxs = [
#      60     i
#      61     for i, m in enumerate(reaction.metabolites)
#      62     if m.metanetx_id not in self.NO_KM_MNX_IDS
#      63 ]
#      64 self._S_kin = self.reaction.S[self._kin_idxs]
#      65 self._metabolites_kin = [reaction.metabolites[i] for i in self._kin_idxs]
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\enkie\modular_rate_law.py:62, in <listcomp>(.0)
#      57 self._denominator = denominator
#      58 self._h = cooperativity
#      59 self._kin_idxs = [
#      60     i
#      61     for i, m in enumerate(reaction.metabolites)
# ---> 62     if m.metanetx_id not in self.NO_KM_MNX_IDS
#      63 ]
#      64 self._S_kin = self.reaction.S[self._kin_idxs]
#      65 self._metabolites_kin = [reaction.metabolites[i] for i in self._kin_idxs]
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\enkie\miriam_metabolite.py:48, in MiriamMetabolite.metanetx_id(self)
#      45 """Gets the MetaNetX identifier of the metabolite or None if the metabolite does
#      46 not exist in MetaNetX."""
#      47 if self._metanetx_id is None:
# ---> 48     self._metanetx_id = Metanetx().to_mnx_compound(
#      49         self._miriam_id, self.UNKNOWN_ID
#      50     )
#      51 if self._metanetx_id == self.UNKNOWN_ID:
#      52     return None
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\enkie\dbs\metanetx.py:270, in Metanetx.to_mnx_compound(self, query_id, default)
#     255 """Map the given compound identifier to a MetaNetX compound.
#     256
#     257 Parameters
#    (...)
#     267     The MetaNetX identifier.
#     268 """
#     269 if not query_id.startswith("MNXM"):
# --> 270     mnx_id = self.cmp_id_to_mnx_id.get(query_id, None)
#     271     if mnx_id is None:
#     272         logger.warning("Could not find MNX ID for: %s.", query_id)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\enkie\dbs\metanetx.py:119, in Metanetx.cmp_id_to_mnx_id(self)
#     116 """Dictionary mapping from metabolite identifiers to MetaNetX identifiers."""
#     117 if self._cmp_id_to_mnx_id_dict is None:
#     118     self._cmp_id_to_mnx_id_dict = dict(
# --> 119         zip(self.chem_xref["source"], self.chem_xref["ID"])
#     120     )
#     121     self._cmp_id_to_mnx_id_dict = {
#     122         k: v for (k, v) in self._cmp_id_to_mnx_id_dict.items() if not pd.isna(v)
#     123     }
#     125     # Add curated entries.
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\enkie\dbs\metanetx.py:78, in Metanetx.chem_xref(self)
#      75 @property
#      76 def chem_xref(self) -> pd.DataFrame:
#      77     """Get the CHEM_XREF MetaNetX table."""
# ---> 78     return self._get_mnx_file(MnxFile.CHEM_XREF)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\enkie\dbs\metanetx.py:353, in Metanetx._get_mnx_file(self, file)
#     350     logger.debug("Downloading file from: %s.", file_url)
#     352     # Download the file and only retain the columns we need.
# --> 353     df = pd.read_csv(
#     354         file_url,
#     355         sep="\t",
#     356         comment="#",
#     357         usecols=self.COLUMNS[file][0],
#     358         names=self.COLUMNS[file][1],
#     359     )
#     360     df.to_csv(file_path, sep="\t", index=False)
#     362 # Load the file from disk and add it to the files dictionary.
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\pandas\io\parsers.py:605, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     600 kwds_defaults = _refine_defaults_read(
#     601     dialect, delimiter, delim_whitespace, engine, sep, defaults={"delimiter": ","}
#     602 )
#     603 kwds.update(kwds_defaults)
# --> 605 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\pandas\io\parsers.py:457, in _read(filepath_or_buffer, kwds)
#     454 _validate_names(kwds.get("names", None))
#     456 # Create the parser.
# --> 457 parser = TextFileReader(filepath_or_buffer, **kwds)
#     459 if chunksize or iterator:
#     460     return parser
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\pandas\io\parsers.py:814, in TextFileReader.__init__(self, f, engine, **kwds)
#     811 if "has_index_names" in kwds:
#     812     self.options["has_index_names"] = kwds["has_index_names"]
# --> 814 self._engine = self._make_engine(self.engine)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\pandas\io\parsers.py:1045, in TextFileReader._make_engine(self, engine)
#    1041     raise ValueError(
#    1042         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1043     )
#    1044 # error: Too many arguments for "ParserBase"
# -> 1045 return mapping[engine](self.f, **self.options)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\pandas\io\parsers.py:1862, in CParserWrapper.__init__(self, src, **kwds)
#    1859 kwds["usecols"] = self.usecols
#    1861 # open handles
# -> 1862 self._open_handles(src, kwds)
#    1863 assert self.handles is not None
#    1864 for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\pandas\io\parsers.py:1357, in ParserBase._open_handles(self, src, kwds)
#    1353 def _open_handles(self, src: FilePathOrBuffer, kwds: Dict[str, Any]) -> None:
#    1354     """
#    1355     Let the readers open IOHanldes after they are done with their potential raises.
#    1356     """
# -> 1357     self.handles = get_handle(
#    1358         src,
#    1359         "r",
#    1360         encoding=kwds.get("encoding", None),
#    1361         compression=kwds.get("compression", None),
#    1362         memory_map=kwds.get("memory_map", False),
#    1363         storage_options=kwds.get("storage_options", None),
#    1364     )
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\pandas\io\common.py:558, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     555     mode += "b"
#     557 # open URLs
# --> 558 ioargs = _get_filepath_or_buffer(
#     559     path_or_buf,
#     560     encoding=encoding,
#     561     compression=compression,
#     562     mode=mode,
#     563     storage_options=storage_options,
#     564 )
#     566 handle = ioargs.filepath_or_buffer
#     567 handles: List[Buffer]
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\pandas\io\common.py:288, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     284 if storage_options:
#     285     raise ValueError(
#     286         "storage_options passed with file object or non-fsspec file path"
#     287     )
# --> 288 req = urlopen(filepath_or_buffer)
#     289 content_encoding = req.headers.get("Content-Encoding", None)
#     290 if content_encoding == "gzip":
#     291     # Override compression based on Content-Encoding header
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\site-packages\pandas\io\common.py:194, in urlopen(*args, **kwargs)
#     188 """
#     189 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     190 the stdlib.
#     191 """
#     192 import urllib.request
# --> 194 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\urllib\request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\urllib\request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\urllib\request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\urllib\request.py:1397, in HTTPSHandler.https_open(self, req)
#    1396 def https_open(self, req):
# -> 1397     return self.do_open(http.client.HTTPSConnection, req,
#    1398         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\Diego Alba\.conda\envs\ODBM2\lib\urllib\request.py:1357, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1354         h.request(req.get_method(), req.selector, req.data, headers,
#    1355                   encode_chunked=req.has_header('Transfer-encoding'))
#    1356     except OSError as err: # timeout error
# -> 1357         raise URLError(err)
#    1358     r = h.getresponse()
#    1359 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1131)>

# %%
parameter_space = ParameterSpace(
    [PGM],
    [],
    [P62707],
    [_2pg, _3pg],
    CompartmentParameters.load("e_coli")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Diego Alba\Documents\GitHub\ECFERS\src\kinetic_estimator\ENKIE\enkie_test.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> parameter_space = ParameterSpace(
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>     [PGM],
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     [PGM_law_1],
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a>     [P62707],
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     [_2pg, _3pg],
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a>     CompartmentParameters.load("e_coli")
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Alba/Documents/GitHub/ECFERS/src/kinetic_estimator/ENKIE/enkie_test.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> )
#
# NameError: name 'PGM_law_1' is not defined
