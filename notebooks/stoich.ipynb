# %%
import gzip
import json
import os
import sys
import math
import re

import numpy as np
import pandas as pd

from brendapyrser import BRENDA
from equilibrator_api import ComponentContribution
from itertools import filterfalse
os.chdir('..')
path = os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       8 import numpy as np
#       9 import pandas as pd
# ---> 11 from brendapyrser import BRENDA
#      12 from equilibrator_api import ComponentContribution
#      13 from itertools import filterfalse
#
# ModuleNotFoundError: No module named 'brendapyrser'

# %%
path
# Out:
# '/workspaces/ECFERS'

# %%
with gzip.open(path+"/src/thermo_calculations/kegg_enzymes.json.gz", "r") as f:
        ECs = {e['EC']:e['reaction_ids'] for e in json.load(f)}

with gzip.open(path+"/src/thermo_calculations/kegg_reactions.json.gz", "r") as f:
        RXNs = {r['RID']:r['reaction'] for r in json.load(f)}

reaction_og = pd.read_csv(path+'/src/frenda_brenda/Files/Reaction.csv')
sbm_og = pd.read_csv(path+'/src/frenda_brenda/Files/SpeciesBaseMechanisms.csv')
inac = pd.read_csv(path+'/src/frenda_brenda/Files/Inaccessible_IDs.csv')
kcats = pd.read_csv(path+'/src/kinetic_estimator/full_report_kcats.csv')
kms = pd.read_csv(path+'/src/kinetic_estimator/full_report_kms.csv')
kis = pd.read_csv(path+'/src/kinetic_estimator/full_report_kis.csv')
metabconc_ref = pd.read_csv(path+'/src/frenda_brenda/Files/Metabolite_Concentrations.csv')
dataFile = path+'/src/frenda_brenda/Files/brenda_download.txt'

# %%
brenda = BRENDA(dataFile)
cc = ComponentContribution()
compound_dict = {}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 brenda = BRENDA(dataFile)
# ----> 2 cc = ComponentContribution()
#       3 compound_dict = {}
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/equilibrator_api/component_contribution.py:148, in ComponentContribution.__init__(self, rmse_inf, ccache, predictor)
#     143 if rmse_inf is not None:
#     144     assert rmse_inf.check(
#     145         "[energy]/[substance]"
#     146     ), "rmse_inf must be in units of kJ/mol (or equivalent)"
# --> 148 self.ccache = ccache or create_compound_cache_from_zenodo()
#     150 if predictor is None:
#     151     parameters = CCModelParameters.from_zenodo()
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/equilibrator_cache/api.py:73, in create_compound_cache_from_zenodo(settings)
#      56 def create_compound_cache_from_zenodo(
#      57     settings: ZenodoSettings = DEFAULT_COMPOUND_CACHE_SETTINGS,
#      58 ) -> CompoundCache:
#      59     """
#      60     Initialize a compound cache from Zenodo.
#      61
#    (...)
#      71
#      72     """
# ---> 73     path = get_cached_filepath(settings)
#      74     return create_compound_cache_from_sqlite_file(path)
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/equilibrator_cache/zenodo.py:195, in get_cached_filepath(settings)
#     193 logging.info("Fetching a new version of the Compound Cache from Zenodo.")
#     194 try:
# --> 195     dataframe_dict = get_zenodo_files(settings)
#     196 except JSONDecodeError:
#     197     raise IOError(
#     198         "Some required data needs to be downloaded from Zenodo.org, but "
#     199         "there is a communication problem at the "
#     200         "moment. Please wait and try again later."
#     201     )
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/equilibrator_cache/zenodo.py:157, in get_zenodo_files(settings, timeout)
#     155     fnames = [d["key"] for d in data["files"]]
#     156     urls = [d["links"]["self"] for d in data["files"]]
# --> 157     data_streams = [download_from_url(client, url) for url in urls]
#     158 return dict(zip(fnames, data_streams))
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/equilibrator_cache/zenodo.py:157, in <listcomp>(.0)
#     155     fnames = [d["key"] for d in data["files"]]
#     156     urls = [d["links"]["self"] for d in data["files"]]
# --> 157     data_streams = [download_from_url(client, url) for url in urls]
#     158 return dict(zip(fnames, data_streams))
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/tenacity/__init__.py:333, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     331 @_utils.wraps(f)
#     332 def wrapped_f(*args, **kw):
# --> 333     return self(f, *args, **kw)
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/tenacity/__init__.py:423, in Retrying.__call__(self, fn, *args, **kwargs)
#     420 retry_state = RetryCallState(
#     421     retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     422 while True:
# --> 423     do = self.iter(retry_state=retry_state)
#     424     if isinstance(do, DoAttempt):
#     425         try:
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/tenacity/__init__.py:372, in BaseRetrying.iter(self, retry_state)
#     370     retry_exc = self.retry_error_cls(fut)
#     371     if self.reraise:
# --> 372         raise retry_exc.reraise()
#     373     six.raise_from(retry_exc, fut.exception())
#     375 if self.wait:
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/tenacity/__init__.py:189, in RetryError.reraise(self)
#     187 def reraise(self):
#     188     if self.last_attempt.failed:
# --> 189         raise self.last_attempt.result()
#     190     raise self
#
# File /opt/conda/envs/myenv/lib/python3.9/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/envs/myenv/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/tenacity/__init__.py:426, in Retrying.__call__(self, fn, *args, **kwargs)
#     424 if isinstance(do, DoAttempt):
#     425     try:
# --> 426         result = fn(*args, **kwargs)
#     427     except BaseException:
#     428         retry_state.set_exception(sys.exc_info())
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/equilibrator_cache/zenodo.py:131, in download_from_url(client, url)
#     129 except KeyError:
#     130     total = float("inf")
# --> 131 md5 = response.headers["content-md5"]
#     133 num_bytes = 0
#     134 with tqdm(
#     135     total=total, unit_scale=True, unit_divisor=1024, unit="B"
#     136 ) as progress:
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/httpx/_models.py:230, in Headers.__getitem__(self, key)
#     227 if items:
#     228     return ", ".join(items)
# --> 230 raise KeyError(key)
#
# KeyError: 'content-md5'

# %%
class ECIndexError(Exception):
    pass

# %%
def manualEC(sbm, reaction, inac):
    inac = inac.dropna()
    # Appending data to sbm DataFrame
    sbm_rows = []
    for index, row in inac.iterrows():
        sbm_row = pd.DataFrame({'Label': row['Accession Number'],
                                'EC': row['EC'],
                                'Type': 'Enzyme',
                                'StartingConc': row['Conc'],
                                'Conc': np.nan,
                                'Mechanisms': np.nan,
                                'Parameters': np.nan,
                                'Species': np.nan}, index=[0])
        sbm_rows.append(sbm_row)

    if sbm_rows:
        sbm = pd.concat([sbm] + sbm_rows, ignore_index=True)

    # Appending data to reaction DataFrame
    reaction_rows = []
    for index, row in inac.iterrows():
        reaction_row = pd.DataFrame({'Accession Number': row['Accession Number'],
                                     'EC': row['EC'],
                                     'Species': np.nan,
                                     'Label': np.nan,
                                     'Enzyme': np.nan,
                                     'Reaction ID': np.nan,
                                     'Mechanism': np.nan,
                                     'Substrates': np.nan,
                                     'Products': np.nan,
                                     'Km': np.nan,
                                     'Kcat': np.nan,
                                     'Inhibitors': np.nan,
                                     'KI': np.nan}, index=[0])
        reaction_rows.append(reaction_row)

    if reaction_rows:
        reaction = pd.concat([reaction] + reaction_rows, ignore_index=True)

    return sbm, reaction

# %%
def get_enzyme_name(reaction):
    return reaction.name

# %%
def get_substrates_and_products(EC):
    try:
        rxn_IDs = ECs[EC]
    except KeyError:
        raise ECIndexError("This EC is not present in the KEGG database")

    rxn_comp = []

    for rxn in rxn_IDs:
        try:
            substrate = [str(abs(species[0])) + ' ' + species[1] for species in RXNs[rxn] if species[0] <= 0]
            products = [str(abs(species[0])) + ' ' + species[1] for species in RXNs[rxn] if species[0] >= 0]
        except KeyError:
            print('Could not index ',rxn)
            continue
        rxn_comp.append([rxn, substrate, products])

    df = pd.DataFrame(rxn_comp, columns=['Reaction ID', 'Substrates', 'Products'])

    # Remove the brackets from the DataFrame
    df = df.applymap(lambda x: '; '.join(x) if isinstance(x, list) else x)

    return df

# %% [markdown]
# Add stoichiometry to the existing Reaction CSV instead of fixing the base frenda code

# %%
import gzip
import json

# %%
import pandas as pd
import os 
os.chdir('..')

os.getcwd()
# Out:
# '/workspaces/ECFERS'

# %%
with gzip.open("src/thermo_calculations/kegg_reactions.json.gz", "r") as f:
        RXNs = {r['RID']:r['reaction'] for r in json.load(f)}

# %%
filtered_rxn = pd.read_csv('src/frenda_brenda/Files/Model Reduction Approaches/Reaction_filtByMap.csv')

# %%
RXNs['R00519']
# Out:
# [[-1, 'C00003'], [1, 'C00004'], [1, 'C00011'], [-1, 'C00058'], [1, 'C00080']]

# %%
# Create a copy of the original dataframe
filtered_rxn_copy = filtered_rxn.copy()

for index, row in filtered_rxn_copy.iterrows():
    RID = row['Reaction ID']
    print(row['Reaction ID'])
    subs = []
    prods = []
    for cpd in RXNs[RID]:
        if cpd[0] < 0:
            subs.append(cpd)
        elif cpd[0] > 0:
            prods.append(cpd)
        elif cpd[0] == 0:
            subs.append([-1, cpd[1]])  # Change to -1 for subs
            prods.append([1, cpd[1]])  # Change to 1 for prods

    # Format the substrates and products
    formattedsubs = "; ".join([f"{int(item[0])} {item[1]}" for item in subs])
    formattedprods = "; ".join([f"{int(item[0])} {item[1]}" for item in prods])
    
    # Update the copy of the dataframe with the new values
    filtered_rxn_copy.at[index, 'Substrates'] = formattedsubs
    filtered_rxn_copy.at[index, 'Products'] = formattedprods

# The filtered_rxn_copy dataframe now contains the updated Substrates and Products columns

# %%
filtered_rxn_copy.to_csv('src/frenda_brenda/Files/Model Reduction Approaches/Reaction_filtByMap_withStoich.csv')

# %% [markdown]
# Fixing concentrations

# %%
proteome = pd.read_csv('src/frenda_brenda/Files/proteome_exe.csv', header=None)
sbmplain = pd.read_csv('src/frenda_brenda/Files/SpeciesBaseMechanisms.csv')
sbmfilt = pd.read_csv('src/frenda_brenda/Files/Model Reduction Approaches/SpeciesBaseMechanism_filtByMap.csv')

# %%
ecdict = dict(zip(sbmplain['EC'], sbmplain['Label']))

# %%
concdict = dict(zip(proteome[proteome.columns[0]], proteome[proteome.columns[1]]))

# %%
concdict['WP_001307570.1']*0.36526946
# Out:
# 17.35029935

# %%
sbmfilt_copy = sbmfilt.copy()
for index, row in sbmfilt.iterrows():
    if pd.notna(row['EC']):  # Check if the value is not NaN
        try:
            print(ecdict[row['EC']])
            conc = ((concdict[ecdict[row['EC']]]*0.36526946)/1000)
            sbmfilt_copy.at[index, 'StartingConc'] = conc
        except KeyError:
            print(row['Label'])
# Out:
# WP_000099534.1
# WP_001181473.1
# WP_000153502.1
# WP_000003829.1
# WP_000597260.1
# WP_000102485.1
# WP_000025458.1
# WP_000111269.1
# WP_000036723.1
# WP_000098614.1
# WP_000963518.1
# WP_000024939.1
# WP_001295461.1
# WP_001295272.1
# WP_000130189.1
# WP_000069410.1
# WP_000099823.1
# WP_001265681.1
# WP_000919159.1
# WP_000066639.1
# WP_000785834.1
# WP_000069437.1
# WP_001295373.1
# WP_000043460.1
# WP_000462687.1
# WP_000527955.1
# WP_000506490.1
# WP_000136788.1
# WP_001005579.1
# WP_001186650.1
# WP_000195061.1
# WP_000034372.1
# WP_001220233.1
# WP_000210878.1
# WP_000334099.1
# WP_001062128.1
# WP_000695655.1
# WP_001293003.1
# WP_001295403.1
# WP_000086722.1
# WP_000988027.1
# WP_001299507.1
# WP_001127419.1
# WP_001295247.1
# WP_001300978.1
# WP_001120798.1
# WP_000817178.1
# WP_001271717.1
# WP_000138270.1
# WP_001320168.1
# WP_000963837.1
# WP_000342648.1
# WP_001230087.1
# WP_000078239.1
# WP_001298109.1
# WP_001216325.1
# WP_000193841.1
# WP_000811065.1
# WP_000207665.1
# WP_001320171.1
# WP_001287154.1
# WP_001213837.1
# WP_000057149.1
# WP_000045290.1
# WP_000208515.1
# WP_000068701.1
# WP_000095707.1
# WP_000354622.1
# WP_000941942.1
# WP_001021161.1
# WP_000587764.1
# WP_000301720.1
# WP_000351477.1
# WP_000284050.1
# WP_000055072.1
# WP_000191372.1
# WP_000646014.1
# WP_000844219.1
# WP_000045178.1
# WP_000227927.1
# WP_000133580.1
# WP_001130211.1
# WP_000288146.1
# WP_000175052.1
# WP_000130048.1
# WP_001289167.1
# WP_000818618.1
# WP_000071134.1
# WP_000551807.1
# WP_001187559.1
# WP_001300904.1
# WP_000800512.1
# WP_000189743.1
# WP_001295286.1
# WP_000700894.1
# WP_000591795.1
# WP_000423729.1
# WP_000555849.1
# WP_001300813.1
# WP_000553451.1
# WP_000857856.1
# WP_001192973.1
# WP_000816480.1
# WP_000699450.1
# WP_001008532.1
# WP_001301272.1
# WP_000860273.1
# WP_000689844.1
# WP_001181706.1
# WP_001109196.1
# WP_000593273.1
# WP_000636571.1
# WP_001295473.1
# WP_000626410.1
# WP_000905386.1
# WP_000081903.1
# WP_000683335.1
# WP_000177906.1
# WP_001303675.1
# WP_000433476.1
# WP_000357259.1
# WP_001338652.1
# WP_000611804.1
# WP_000963792.1
# WP_000160808.1
# WP_000153940.1
# WP_000176278.1
# WP_000586449.1
# WP_000224714.1
# WP_000970117.1
# WP_000211907.1
# WP_001295467.1
# WP_000871512.1
# WP_000080085.1
# WP_000789986.1
# WP_000397144.1
# WP_000853753.1
# WP_000816280.1
# WP_000127356.1
# WP_000089084.1
# WP_000853869.1
# WP_000639996.1
# WP_000332036.1
# WP_001217335.1
# WP_000893272.1
# WP_001291990.1
# WP_000493947.1
# WP_001058802.1
# WP_001151604.1
# WP_001302318.1
# WP_001109486.1
# WP_000866792.1
# WP_000816234.1
# WP_001170661.1
# WP_000131757.1
# WP_000337081.1
# WP_000219193.1
# WP_000224573.1
# WP_000818411.1
# WP_000998544.1
# WP_001298007.1
# WP_000785116.1
# WP_000473109.1
# WP_000197884.1
# WP_001354020.1
# WP_000765749.1
# WP_000301651.1
# WP_000137657.1
# WP_001297412.1
# WP_000781063.1
# WP_000806177.1
# WP_000857508.1
# WP_012767740.1
# WP_000796481.1
# WP_000584546.1
# WP_001295331.1
# WP_001100801.1
# WP_001295412.1
# WP_001043882.1
# WP_000935370.1
# WP_000626688.1
# WP_000486988.1
# WP_001175605.1
# WP_001257000.1
# WP_000148581.1
# WP_001207520.1
# WP_001076997.1
# WP_001139613.1
# WP_000842100.1
# WP_000621515.1
# WP_000762229.1
# WP_000105579.1
# WP_001234777.1
# WP_000183060.1
# WP_000187778.1
# WP_001090386.1
# WP_000886900.1
# WP_000030740.1
# WP_001096048.1
# WP_001044366.1
# WP_001297933.1
# WP_000108921.1
# WP_000126543.1
# WP_000096674.1
# WP_000030016.1
# WP_000424181.1
# WP_000153129.1
# WP_000108330.1
# WP_000445249.1
# WP_000039863.1
# WP_000805449.1
# WP_001285288.1
# WP_001135174.1
# WP_000951213.1
# WP_001023616.1
# WP_000589409.1
# WP_000110749.1
# WP_001295474.1
# WP_001060244.1
# Isocitrate dehydrogenase (nadp+)
# WP_001295272.1
# WP_000626410.1
# Pyruvate carboxylase
# Formate dehydrogenase
# WP_000597260.1
# WP_000069437.1
# WP_001295373.1
# WP_000527955.1
# WP_000136788.1
# WP_001186650.1
# WP_001220233.1
# WP_000210878.1
# WP_000334099.1
# WP_000695655.1
# WP_001293003.1
# WP_000988027.1
# WP_001299507.1
# WP_001300978.1
# WP_001120798.1
# WP_000138270.1
# WP_001320168.1
# WP_000963837.1
# WP_001230087.1
# WP_000193841.1
# WP_000811065.1
# WP_000207665.1
# WP_001287154.1
# WP_000045290.1
# WP_000941942.1
# WP_001021161.1
# WP_000587764.1
# WP_000351477.1
# WP_000284050.1
# WP_000055072.1
# WP_000844219.1
# WP_000045178.1
# WP_000133580.1
# WP_000175052.1
# WP_000130048.1
# WP_000071134.1
# WP_000551807.1
# WP_001300904.1
# WP_001295286.1
# WP_000700894.1
# WP_000423729.1
# WP_001300813.1
# WP_000553451.1
# WP_000699450.1
# WP_001301272.1
# WP_000860273.1
# WP_001295473.1
# WP_000081903.1
# WP_000683335.1
# WP_000177906.1
# WP_000357259.1
# WP_000963792.1
# WP_000160808.1
# WP_000176278.1
# WP_000586449.1
# WP_000224714.1
# WP_000970117.1
# WP_000211907.1
# WP_001295467.1
# WP_000871512.1
# WP_000080085.1
# WP_000397144.1
# WP_000127356.1
# WP_000853869.1
# WP_000639996.1
# WP_000332036.1
# WP_001217335.1
# WP_000893272.1
# WP_001291990.1
# WP_000493947.1
# WP_001302318.1
# WP_000866792.1
# WP_001170661.1
# WP_000131757.1
# WP_000337081.1
# WP_000219193.1
# WP_000224573.1
# WP_000998544.1
# WP_001298007.1
# WP_000785116.1
# WP_000473109.1
# WP_000197884.1
# WP_001354020.1
# WP_000765749.1
# WP_000137657.1
# WP_001297412.1
# WP_000806177.1
# WP_000857508.1
# WP_012767740.1
# WP_000796481.1
# WP_000584546.1
# WP_001295331.1
# WP_001100801.1
# WP_000935370.1
# WP_000626688.1
# WP_001175605.1
# WP_001257000.1
# WP_000148581.1
# WP_001207520.1
# WP_001076997.1
# WP_001139613.1
# WP_000105579.1
# WP_001234777.1
# WP_000183060.1
# WP_000187778.1
# WP_001090386.1
# WP_000886900.1
# WP_000030740.1
# WP_001096048.1
# WP_000126543.1
# WP_000096674.1
# WP_000030016.1
# WP_000424181.1
# WP_000153129.1
# WP_000039863.1
# WP_001285288.1
# WP_001135174.1
# WP_000951213.1
# WP_001023616.1
# WP_000589409.1
# WP_001295474.1
# WP_001060244.1
# Atp citrate synthase

# %%
sbmfilt_copy.to_csv('src/frenda_brenda/Files/Model Reduction Approaches/SpeciesBaseMechanism_filtByMap.csv')

# %% [markdown]
# extra to add inhibitors

# %%
import pandas as pd

# %%
missing_kis = pd.read_csv('/workspaces/ECFERS/notebooks/241023_missing_kis.csv')
rxn = pd.read_csv('/workspaces/ECFERS/src/frenda_brenda/Files/Model Reduction Approaches/Reaction_filtByMap_withStoich.csv')
sbm = pd.read_csv('/workspaces/ECFERS/src/frenda_brenda/Files/Model Reduction Approaches/SpeciesBaseMechanism_filtByMap.csv')

# %%
# Filter and group by enzyme, creating lists only for substrates starting with "C"
inhibitor_ki_dict = {}
for enzyme, group in missing_kis.groupby('enzyme'):
    filtered_group = group[group['substrates'].str.startswith('C')]
    
    inhibitors = ';'.join(filtered_group['substrates'])
    KIs = ';'.join([f"{substrate}_KI: {km}" for substrate, km in zip(filtered_group['substrates'], filtered_group['Km'])])
    
    inhibitor_ki_dict[enzyme] = {'Inhibitors': inhibitors, 'KI': KIs}

# Update only rows with matching "EC" in missing_kis
rxn['Inhibitors'] = rxn.apply(
    lambda row: inhibitor_ki_dict[row['EC']]['Inhibitors'] if row['EC'] in inhibitor_ki_dict else row['Inhibitors'],
    axis=1
)
rxn['KI'] = rxn.apply(
    lambda row: inhibitor_ki_dict[row['EC']]['KI'] if row['EC'] in inhibitor_ki_dict else row['KI'],
    axis=1
)

# %%
pd.set_option('display.max_colwidth', None)

# %%
rxn[rxn['EC']=='2.3.3.8']
# Out:
#      Unnamed: 0 Accession Number       EC           Species Label  \
# 122         122              NaN  2.3.3.8  Escherichia coli  R123
#
#                    Enzyme Reaction ID Mechanism  \
# 122  Atp citrate synthase      R00352       MRL
#
#                           Substrates                                Products  \
# 122  -1 C00002; -1 C00010; -1 C00158  1 C00008; 1 C00009; 1 C00024; 1 C00036
#
#                                                                                                                                                                                                                           Km  \
# 122  Km_C00008: 11.421359055528603; Km_C00009: 11.421359055528603; Km_C00024: 11.421359055528603; Km_C00036: 11.421359055528603; Km_C00002: 11.421359055528603; Km_C00010: 11.421359055528603; Km_C00158: 11.421359055528603
#
#                                                      Kcat     Inhibitors  \
# 122  Kcat_F: 19.78221183941891; Kcat_R: 19.78221183941891  C00036;C00008
#
#                                 KI  Keq
# 122  C00036_KI: nan;C00008_KI: nan  NaN
